# %%
import pandas
import numpy as np
import isochrones.isochrones as iso
from isochrones import dartmouth

# %%
dar = dartmouth.Dartmouth_Isochrone()

# %%
ev = dar.evtrack(1.5,dage=0.02)
plot((ev['Teff']),ev['logL'],'.')

# %%
reload(iso)
reload(dartmouth)
dar = dartmouth.Dartmouth_Isochrone()
mod = iso.StarModel(dar,Teff=(5783,64),logg=(4.36,0.07),feh=(-0.06,0.1))#,
                    #H=(9.92,0.04),J=(10.23,0.04),K=(9.85,0.04))

# %%
mod.fit_mcmc()

# %%
mod.plot_samples('radius')
mod.plot_samples('mass')

# %%
from keputils import koiutils as ku

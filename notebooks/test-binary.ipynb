# %%
# %matplotlib inline

import numpy as np

from isochrones.dartmouth import Dartmouth_Isochrone
from isochrones.starmodel import BinaryStarModel, StarModel
from isochrones.starmodel import TripleStarModel

dar = Dartmouth_Isochrone()

# %% [markdown]
# Example: A known EB KIC 6778289, or WISE J192824.57+421508.1 (http://keplerebs.villanova.edu/overview/?k=6778289)

# %%
mags = dict( W1=(11.808,0.022), W2=(11.834,0.021), W3=(11.675,0.170), 
            J=(12.119,0.021), H=(11.913,0.017), K=(11.873,0.019))

mod1 = StarModel(dar, **mags)
mod2 = BinaryStarModel(dar, **mags)
mod3 = TripleStarModel(dar, **mags)

# %%
mod1.fit_mcmc()
#mod2.fit_mcmc()
#mod3.fit_mcmc()

# %%
mod3.triangle_plots();
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-86f22ae9929a> in <module>()
# ----> 1 mod3.triangle_plots();
#
# /Users/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.7.4-py2.7.egg/isochrones/starmodel.pyc in triangle_plots(self, basename, format, **kwargs)
#    1199                             params=['mass_A', 'mass_B', 'mass_C', 'radius',
#    1200                                     'Teff','feh','age','distance'],
# -> 1201                             **kwargs)
#    1202         if basename is not None:
#    1203             plt.savefig('{}_physical.{}'.format(basename,format))
#
# /Users/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.7.4-py2.7.egg/isochrones/starmodel.pyc in triangle(self, params, **kwargs)
#    1218                       'age', 'feh', 'distance', 'AV']
#    1219
# ...

# %%
print np.percentile(mod1.sampler.flatlnprobability, 0.5)
print mod1.sampler.flatlnprobability.min()
# Out:
# -498.340797252
# -815.872382699

# %%
print np.percentile(mod3.sampler.flatlnprobability, 0.5)
print mod3.sampler.flatlnprobability.min()
# Out:
# -236994.692322
# -1571688.18786

# %%
mod1.triangle_plots();

# %%
mod2.triangle_plots();

# %%
mod2.save_hdf('test_binary.h5')

# %%
mod2_2 = BinaryStarModel.load_hdf('test_binary.h5')

# %%
np.all(mod2.samples == mod2_2.samples)
# Out:
# True

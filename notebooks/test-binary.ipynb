# %%
# %matplotlib inline

import numpy as np

from isochrones.dartmouth import Dartmouth_Isochrone
from isochrones.starmodel import BinaryStarModel, StarModel
from isochrones.starmodel import TripleStarModel

dar = Dartmouth_Isochrone()

# %% [markdown]
# Example: A known EB KIC 6778289, or WISE J192824.57+421508.1 (http://keplerebs.villanova.edu/overview/?k=6778289)

# %%
mags = dict( W1=(11.808,0.022), W2=(11.834,0.021), W3=(11.675,0.170), 
            J=(12.119,0.021), H=(11.913,0.017), K=(11.873,0.019))

mod1 = StarModel(dar, maxAV=0.5, **mags)
mod2 = BinaryStarModel(dar, maxAV=0.5, **mags)
mod3 = TripleStarModel(dar, maxAV=0.5, **mags)

# %%
mod1.fit_mcmc()
mod2.fit_mcmc()
mod3.fit_mcmc()
# Out:
# WARNING:root:feh prior is nan at -0.739252573269
# WARNING:root:feh prior is nan at -1.12200170122
# WARNING:root:feh prior is nan at -1.51580713903
# WARNING:root:feh prior is nan at -0.615562683258
# WARNING:root:feh prior is nan at -1.92719386197
# WARNING:root:feh prior is nan at 0.409338870504
# WARNING:root:feh prior is nan at -0.809566247534
# WARNING:root:feh prior is nan at -0.51644773994
# WARNING:root:feh prior is nan at -0.341771188504
# WARNING:root:feh prior is nan at -0.409260726842
# WARNING:root:feh prior is nan at -1.9252671153
# WARNING:root:feh prior is nan at -1.43726100328
# WARNING:root:feh prior is nan at -1.10038100565
# WARNING:root:feh prior is nan at -0.359023258757
# WARNING:root:feh prior is nan at -2.13380212207
# WARNING:root:feh prior is nan at -0.577862438247
# WARNING:root:feh prior is nan at 0.33469633203
# WARNING:root:feh prior is nan at -1.23895431287
# WARNING:root:feh prior is nan at -0.91864505584
# WARNING:root:feh prior is nan at -0.991677128607
# WARNING:root:feh prior is nan at -1.17324897086
# WARNING:root:feh prior is nan at -0.364848522897
# WARNING:root:feh prior is nan at -1.60164972027
# WARNING:root:feh prior is nan at -1.48735171483
# WARNING:root:feh prior is nan at -0.431681194287
# WARNING:root:feh prior is nan at -1.34088976953
# WARNING:root:feh prior is nan at -0.975593552293
# WARNING:root:feh prior is nan at -2.09385835596
# WARNING:root:feh prior is nan at -1.5017768029
# WARNING:root:feh prior is nan at -1.43404569279
# WARNING:root:feh prior is nan at -0.571643821769
# WARNING:root:feh prior is nan at -0.902894973436
# WARNING:root:feh prior is nan at -0.91485986418
# WARNING:root:feh prior is nan at -1.57372965503
# WARNING:root:feh prior is nan at -1.70991002495
# WARNING:root:feh prior is nan at -2.22111476192
# WARNING:root:feh prior is nan at -1.67094486471
# WARNING:root:feh prior is nan at -0.895331143734
# WARNING:root:feh prior is nan at -2.39324820488
# WARNING:root:feh prior is nan at -2.00699065112
# WARNING:root:feh prior is nan at -2.31692167347
# WARNING:root:feh prior is nan at -1.26889229704
# WARNING:root:feh prior is nan at -1.99917075652
# WARNING:root:feh prior is nan at -2.42928530872
# WARNING:root:feh prior is nan at -0.775683958217
# WARNING:root:feh prior is nan at -2.11943634246
# WARNING:root:feh prior is nan at 0.448726799411
# WARNING:root:feh prior is nan at -1.75770636468
# WARNING:root:feh prior is nan at -2.07573938603
# WARNING:root:feh prior is nan at -1.57139509265
# WARNING:root:feh prior is nan at -2.33372933414
# WARNING:root:feh prior is nan at -1.52354448444
# WARNING:root:feh prior is nan at -1.19009047722
# WARNING:root:feh prior is nan at -0.419794464171
# WARNING:root:feh prior is nan at -2.21753694468
# WARNING:root:feh prior is nan at -1.03025541599
# WARNING:root:feh prior is nan at -1.04117186798
# WARNING:root:feh prior is nan at -0.564797335081
# WARNING:root:feh prior is nan at -1.72787772291
# WARNING:root:feh prior is nan at -2.24436458884
# WARNING:root:feh prior is nan at -0.618022633137
# WARNING:root:feh prior is nan at -1.39960394866
# WARNING:root:feh prior is nan at -1.64688977751
# WARNING:root:feh prior is nan at -1.72807082877
# WARNING:root:feh prior is nan at -1.09988616937
# WARNING:root:feh prior is nan at -2.33581499767
# WARNING:root:feh prior is nan at -0.798161562755
# WARNING:root:feh prior is nan at -1.62073159783
# WARNING:root:feh prior is nan at -1.76403376143
# WARNING:root:feh prior is nan at -1.37836474276
# WARNING:root:feh prior is nan at -2.20951291444
# WARNING:root:feh prior is nan at -2.24099478854
# WARNING:root:feh prior is nan at -0.358550866925
# WARNING:root:feh prior is nan at 0.47590922878
# WARNING:root:feh prior is nan at -0.516744456148
# WARNING:root:feh prior is nan at -0.876671921653
# WARNING:root:feh prior is nan at -1.93459951502
# WARNING:root:feh prior is nan at -1.38616489875
# WARNING:root:feh prior is nan at -1.67410960011
# WARNING:root:feh prior is nan at -1.6462937278
# WARNING:root:feh prior is nan at -1.12164774356
# WARNING:root:feh prior is nan at 0.489034126801
# WARNING:root:feh prior is nan at -0.600341311148
# WARNING:root:feh prior is nan at -1.2986435406
# WARNING:root:feh prior is nan at -0.962595121098
# WARNING:root:feh prior is nan at -0.46707184956
# WARNING:root:feh prior is nan at -2.48960986197
# WARNING:root:feh prior is nan at -1.20989174185
# WARNING:root:feh prior is nan at -1.4497015951
# WARNING:root:feh prior is nan at -0.775796549474
# WARNING:root:feh prior is nan at -1.25486552248
# WARNING:root:feh prior is nan at -0.580666801284
# WARNING:root:feh prior is nan at -2.17274277926
# WARNING:root:feh prior is nan at -0.729212676452
# WARNING:root:feh prior is nan at -0.610815885937
# WARNING:root:feh prior is nan at -1.11090596098
# WARNING:root:feh prior is nan at -0.653465264675
# WARNING:root:feh prior is nan at -1.75134420394
# WARNING:root:feh prior is nan at -2.07446586872
# WARNING:root:feh prior is nan at 0.306495840954
# WARNING:root:feh prior is nan at -0.768762886036
# WARNING:root:feh prior is nan at -0.674174375669
# WARNING:root:feh prior is nan at -2.0111141658
# WARNING:root:feh prior is nan at -1.86398107104
# WARNING:root:feh prior is nan at -0.713703546542
# WARNING:root:feh prior is nan at -0.913610769052
# WARNING:root:feh prior is nan at -1.95064580024
# WARNING:root:feh prior is nan at -1.73597879718
# WARNING:root:feh prior is nan at -1.66525362894
# WARNING:root:feh prior is nan at -1.18343037127
# WARNING:root:feh prior is nan at -1.47564017861
# WARNING:root:feh prior is nan at -1.73806239143
# WARNING:root:feh prior is nan at -1.06045540097
# WARNING:root:feh prior is nan at -1.44925641281
# WARNING:root:feh prior is nan at -1.44242716863
# WARNING:root:feh prior is nan at -1.80074749098
# WARNING:root:feh prior is nan at -1.57278097035
# WARNING:root:feh prior is nan at -0.912312640755
# WARNING:root:feh prior is nan at -1.46445671895
# WARNING:root:feh prior is nan at -2.28020999752
# WARNING:root:feh prior is nan at -1.41682119999
# WARNING:root:feh prior is nan at -1.1710947444
# WARNING:root:feh prior is nan at -0.413460180852
# WARNING:root:feh prior is nan at -1.73933443025
# WARNING:root:feh prior is nan at -1.98089892258
# WARNING:root:feh prior is nan at 0.328868804881
# WARNING:root:feh prior is nan at -2.00800194885
# WARNING:root:feh prior is nan at -2.0052770101
# WARNING:root:feh prior is nan at -2.14283159976
# WARNING:root:feh prior is nan at -0.711309129759
# WARNING:root:feh prior is nan at -0.882621772336
# WARNING:root:feh prior is nan at -0.334751241034
# WARNING:root:feh prior is nan at -0.844785748713
# WARNING:root:feh prior is nan at -2.37337219145
# WARNING:root:feh prior is nan at -2.14031146024
# WARNING:root:feh prior is nan at -2.19608014005
# WARNING:root:feh prior is nan at -1.43087084064
# WARNING:root:feh prior is nan at -1.73834751006
# WARNING:root:feh prior is nan at -1.81411149715
# WARNING:root:feh prior is nan at -1.976363281
# WARNING:root:feh prior is nan at 0.493118247521
# WARNING:root:feh prior is nan at -1.17307325788
# WARNING:root:feh prior is nan at -0.908095212635
# WARNING:root:feh prior is nan at -0.350709042052
# WARNING:root:feh prior is nan at -0.657836385329
# WARNING:root:feh prior is nan at -0.488705172486
# WARNING:root:feh prior is nan at -0.915671020334
# WARNING:root:feh prior is nan at -2.0994400319
# WARNING:root:feh prior is nan at -0.794901991181
# WARNING:root:feh prior is nan at -0.7911846619
# WARNING:root:feh prior is nan at -2.10796948107
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7f5e6a10a252> in <module>()
# ----> 1 mod1.fit_mcmc()
#       2 mod2.fit_mcmc()
#       3 mod3.fit_mcmc()
#
# /u/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.8.3-py2.7.egg/isochrones/starmodel.pyc in fit_mcmc(self, nwalkers, nburn, niter, p0, initial_burn, ninitial, loglike_kwargs, **kwargs)
#     455                                                 **kwargs)
#     456                 #ninitial = 300 #should this be parameter?
# --> 457                 pos, prob, state = sampler.run_mcmc(p0, ninitial)
#     458                 wokinds = np.where((sampler.naccepted/ninitial > 0.15) &
#     459                                    (sampler.naccepted/ninitial < 0.4))[0]
#
# /u/tdm/.local/lib/python2.7/site-packages/emcee-2.0.0-py2.7.egg/emcee/sampler.pyc in run_mcmc(self, pos0, N, rstate0, lnprob0, **kwargs)
#     160         """
#     161         for results in self.sample(pos0, lnprob0, rstate0, iterations=N,
# --> 162                                    **kwargs):
#     163             pass
#     164         return results
#
# /u/tdm/.local/lib/python2.7/site-packages/emcee-2.0.0-py2.7.egg/emcee/ensemble.pyc in sample(self, p0, lnprob0, rstate0, blobs0, iterations, thin, storechain, mh_proposal)
#     182         blobs = blobs0
#     183         if lnprob is None:
# --> 184             lnprob, blobs = self._get_lnprob(p)
#     185
#     186         # Check to make sure that the probability function didn't return
#
# /u/tdm/.local/lib/python2.7/site-packages/emcee-2.0.0-py2.7.egg/emcee/ensemble.pyc in _get_lnprob(self, pos)
#     373         # Check for lnprob returning NaN.
#     374         if np.any(np.isnan(lnprob)):
# --> 375             raise ValueError("lnprob returned NaN.")
#     376
#     377         return lnprob, blob
#
# ValueError: lnprob returned NaN.

# %%
mod2.triangle_plots(extent=0.99);

# %%
mod1.triangle_plots();

# %%
mod3.triangle_plots();

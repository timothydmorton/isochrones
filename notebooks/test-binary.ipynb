# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from isochrones.dartmouth import Dartmouth_Isochrone
from isochrones.starmodel import BinaryStarModel, StarModel
from isochrones.starmodel import TripleStarModel

dar = Dartmouth_Isochrone()

# %% [markdown]
# Example: A known EB KIC 6778289, or WISE J192824.57+421508.1 (http://keplerebs.villanova.edu/overview/?k=6778289)

# %%
mags = dict( W1=(11.808,0.022), W2=(11.834,0.021), W3=(11.675,0.170), 
            J=(12.119,0.021), H=(11.913,0.017), K=(11.873,0.019))

mod1 = StarModel(dar, maxAV=0.5, **mags)
mod2 = BinaryStarModel(dar, maxAV=0.5, **mags)
mod3 = TripleStarModel(dar, maxAV=0.5, **mags)

# %%
mod1.fit_mcmc()
mod2.fit_mcmc()
mod3.fit_mcmc()

# %%
mod1.triangle_plots();

# %%
mod2.triangle_plots();
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-1ae76ff090f8> in <module>()
# ----> 1 mod2.triangle_plots();
#
# /u/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.8.3-py2.7.egg/isochrones/starmodel.pyc in triangle_plots(self, basename, format, **kwargs)
#    1113                             params=['mass_A', 'mass_B','radius','Teff','feh','age',
#    1114                                     'distance', 'AV'],
# -> 1115                             **kwargs)
#    1116         if basename is not None:
#    1117             plt.savefig('{}_physical.{}'.format(basename,format))
#
# /u/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.8.3-py2.7.egg/isochrones/starmodel.pyc in triangle(self, params, **kwargs)
#    1151             params = ['mass_A', 'mass_B', 'age', 'feh', 'distance', 'AV']
#    1152
# -> 1153         super(BinaryStarModel, self).triangle(params=params, **kwargs)
#    1154
#    1155
#
# /u/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.8.3-py2.7.egg/isochrones/starmodel.pyc in triangle(self, params, query, extent, **kwargs)
#     558                 params = ['mass', 'age', 'feh']
#     559
# --> 560         df = self.samples
#     561         if query is not None:
#     562             df = df.query(query)
#
# /u/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.8.3-py2.7.egg/isochrones/starmodel.pyc in samples(self)
#     692             df = self._samples
#     693         else:
# --> 694             self._make_samples()
#     695             df = self._samples
#     696
#
# /u/tdm/anaconda/lib/python2.7/site-packages/isochrones-0.8.3-py2.7.egg/isochrones/starmodel.pyc in _make_samples(self)
#    1162         mass_B = self.sampler.chain[ok_walkers,:,1]
#    1163         age = self.sampler.chain[ok_walkers,:,2]
# -> 1164         feh = self.sampler.chain[ok_walkers:,3]
#    1165
#    1166         if self.fit_for_distance:
#
# IndexError: invalid slice

# %%
mod3.triangle_plots();

# %%
plt.plot(mod3.sampler.lnprobability.T);

# %%
plt.plot(mod2.sampler.lnprobability.T);

# %%
plt.plot(mod1.sampler.lnprobability.T);

# %%
np.sort(mod1.sampler.acceptance_fraction)
# Out:
# array([ 0.   ,  0.   ,  0.01 ,  0.015,  0.03 ,  0.035,  0.07 ,  0.08 ,
#         0.08 ,  0.105,  0.12 ,  0.125,  0.125,  0.13 ,  0.135,  0.14 ,
#         0.145,  0.15 ,  0.15 ,  0.155,  0.16 ,  0.16 ,  0.165,  0.165,
#         0.165,  0.165,  0.165,  0.17 ,  0.17 ,  0.175,  0.18 ,  0.18 ,
#         0.18 ,  0.185,  0.185,  0.185,  0.185,  0.185,  0.19 ,  0.19 ,
#         0.195,  0.195,  0.195,  0.195,  0.195,  0.2  ,  0.2  ,  0.2  ,
#         0.205,  0.205,  0.205,  0.21 ,  0.21 ,  0.21 ,  0.21 ,  0.215,
